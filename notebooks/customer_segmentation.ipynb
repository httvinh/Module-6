# %%
# %load_ext autoreload
# %autoreload 2

# Import thư viện
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd

from pgk import DataCleaner
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_path = '../data/online_retail.csv'

cleaner = DataCleaner(data_path=data_path)
df = cleaner.load_data()
df.head()
# Out:
# ../data/online_retail.csv
# Data loaded with shape: (541909, 8)
# Data loaded has samples: 541909
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df_uk = cleaner.clean_data()
df_uk.info()
# Out:
# Data after removing canceled orders: (532621, 9)
# Data after removing non-positive Quantity or UnitPrice: (530104, 9)
# Data after removing null CustomerID: (397884, 9)
# Data after filtering UK customers: (354321, 9)
# <class 'pandas.core.frame.DataFrame'>
# Index: 354321 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    354321 non-null  object
#  1   StockCode    354321 non-null  object
#  2   Description  354321 non-null  object
#  3   Quantity     354321 non-null  int64
#  4   InvoiceDate  354321 non-null  datetime64[ns]
#  5   UnitPrice    354321 non-null  float64
#  6   CustomerID   354321 non-null  object
#  7   Country      354321 non-null  object
#  8   TotalPrice   354321 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 27.0+ MB

# %%
cleaner.create_time_features()
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     017850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     017850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
#
#    InvoiceDayOfWeek  InvoiceHour
# 0                 2            8
# 1                 2            8
# ...
